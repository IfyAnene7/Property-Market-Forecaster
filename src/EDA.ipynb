# %% [markdown]
# # Property price predictor in Tunisia

# %% [markdown]
# #### Names of contributors: Anene Ifeanyi

# %% [markdown]
# #### Date: 2020-12-27

# %%
# Import required eda packages

import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
RE_df = pd.read_csv("../data/raw/pp_in_tunisia.csv")

RE_df
# Out:
#                     category  room_count  bathroom_count   size      type  \
# 0         Terrains et Fermes        -1.0            -1.0   -1.0  À Vendre
# 1         Terrains et Fermes        -1.0            -1.0   -1.0  À Vendre
# 2               Appartements         2.0             1.0   80.0   À Louer
# 3      Locations de vacances         1.0             1.0   90.0   À Louer
# 4               Appartements         2.0             2.0  113.0  À Vendre
# ...                      ...         ...             ...    ...       ...
# 12743     Terrains et Fermes        -1.0            -1.0   -1.0  À Vendre
# 12744           Appartements         1.0             1.0  100.0   À Louer
# 12745      Maisons et Villas         3.0             1.0  760.0  À Vendre
# 12746      Maisons et Villas         3.0             1.0  190.0  À Vendre
# 12747      Maisons et Villas         2.0             1.0   70.0   À Louer
#
#            price    city         region  log_price
# ...

# %%
pd.DataFrame(RE_df.groupby(["category"]))
# Out:
#                                            0  \
# 0                               Appartements
# 1                        Bureaux et Plateaux
# 2                                Colocations
# 3                      Locations de vacances
# 4  Magasins, Commerces et Locaux industriels
# 5                          Maisons et Villas
# 6                         Terrains et Fermes
#
#                                                    1
# 0             category  room_count  bathroom_coun...
# 1                    category  room_count  bathro...
# 2            category  room_count  bathroom_count...
# 3                      category  room_count  bath...
# 4                                          catego...
# 5                  category  room_count  bathroom...
# 6                   category  room_count  bathroo...

# %%
pd.DataFrame(RE_df.groupby(["type"]))
# Out:
#           0                                                  1
# 0   À Louer                                          catego...
# 1  À Vendre                   category  room_count  bathroo...
